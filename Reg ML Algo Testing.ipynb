# %% [markdown]
# # Benchmark QRT
#
# This notebook illustrates a simple benchmark example that should help novice participants to start the competition.
#
# ## Used libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

# %% [markdown]
# ## Loading data
#
# The train and test inputs are composed of 46 features.
#
# The target of this challenge is `RET` and corresponds to the fact that the **return is in the top 50% of highest stock returns**.
#
# Since the median is very close to 0, this information should not change much with the idea to predict the sign of the return.

# %%
x_train = pd.read_csv('C:\\Users\\aryje\\OneDrive\\Stalinis kompiuteris\\Durhack\\x_train.csv', index_col='ID')
y_train = pd.read_csv('C:\\Users\\aryje\\OneDrive\\Stalinis kompiuteris\\Durhack\\y_train.csv', index_col='ID')
train = pd.concat([x_train, y_train], axis=1)
test = pd.read_csv('C:\\Users\\aryje\\OneDrive\\Stalinis kompiuteris\\Durhack\\x_test.csv', index_col='ID')
train.head()
# Out:
#     DATE  STOCK  INDUSTRY  INDUSTRY_GROUP  SECTOR  SUB_INDUSTRY     RET_1  \
# ID
# 0      0      2        18               5       3            44 -0.015748
# 1      0      3        43              15       6           104  0.003984
# 2      0      4        57              20       8           142  0.000440
# 3      0      8         1               1       1             2  0.031298
# 4      0     14        36              12       5            92  0.027273
#
#     VOLUME_1     RET_2  VOLUME_2  ...  VOLUME_16    RET_17  VOLUME_17  \
# ID                                ...
# 0   0.147931 -0.015504  0.179183  ...   0.630899  0.003254  -0.379412
# 1        NaN -0.090580       NaN  ...        NaN  0.003774        NaN
# 2  -0.096282 -0.058896  0.084771  ...  -0.010336 -0.017612  -0.354333
# 3  -0.429540  0.007756 -0.089919  ...   0.012105  0.033824  -0.290178
# 4  -0.847155 -0.039302 -0.943033  ...  -0.277083 -0.012659   0.139086
#
#       RET_18  VOLUME_18    RET_19  VOLUME_19    RET_20  VOLUME_20    RET
# ID
# 0   0.008752  -0.110597 -0.012959   0.174521 -0.002155  -0.000937   True
# 1  -0.018518        NaN -0.028777        NaN -0.034722        NaN   True
# 2  -0.006562  -0.519391 -0.012101  -0.356157 -0.006867  -0.308868  False
# 3  -0.001468  -0.663834 -0.013520  -0.562126 -0.036745  -0.631458  False
# 4   0.004237  -0.017547  0.004256   0.579510 -0.040817   0.802806  False
#
# [5 rows x 47 columns]

# %%
x_train.VOLUME_1.isna().value_counts()
# Out:
# False    353570
# True      65025
# Name: VOLUME_1, dtype: int64

# %% [markdown]
# ## Feature Engineering
#
# The main drawback in this challenge would be to deal with the noise. To do that, we could create some feature that aggregate features with some statistics.
#
# The following cell computes statistics on a given target conditionally to some features. For example, we want to generate a feature that describe the mean of `RET_1` conditionally to the `SECTOR` and the `DATE`.
#
# **Ideas of improvement**: change shifts, the conditional features, the statistics, and the target.

# %%
# Feature engineering
new_features = []

# Conditional aggregated features
shifts = [10] # Choose some different shifts
statistics = ['mean', 'std']  # the type of stat
gb_features = ['SECTOR', 'DATE', 'INDUSTRY']
target_feature = 'RET'
tmp_name = '_'.join(gb_features)
for shift in shifts:
    for stat in statistics:
        name = f'{target_feature}_{shift}_{tmp_name}_{stat}'
        feat = f'{target_feature}_{shift}'
        new_features.append(name)
        for data in [train, test]:
            data[name] = data.groupby(gb_features)[feat].transform(stat)

# %% [markdown]
# ## Feature selection
#
# To reduce the number of feature (and the noise) we only consider the 5 last days of `RET` and `VOLUME` in addition to the newly created feature.

# %%
target = 'RET'

n_shifts = 5  # If you don't want all the shifts to reduce noise
features = ['RET_%d' % (i + 1) for i in range(n_shifts)]
features += new_features  # The conditional features
train[features].head()
# Out:
#        RET_1     RET_2     RET_3     RET_4     RET_5  \
# ID
# 0  -0.015748 -0.015504  0.010972 -0.014672  0.016483
# 1   0.003984 -0.090580  0.018826 -0.025540 -0.038062
# 2   0.000440 -0.058896 -0.009042  0.024852  0.009354
# 3   0.031298  0.007756 -0.004632 -0.019677  0.003544
# 4   0.027273 -0.039302  0.000000  0.000000  0.022321
#
#     RET_1_SECTOR_DATE_INDUSTRY_mean  RET_1_SECTOR_DATE_INDUSTRY_std  \
# ID
# 0                          0.008289                        0.017973
# 1                          0.000671                        0.026857
# 2                          0.012713                        0.031950
# 3                          0.030315                        0.022465
# 4                          0.004413                        0.012243
#
#     RET_1_SECTOR_DATE_INDUSTRY_var  RET_2_SECTOR_DATE_INDUSTRY_mean  \
# ID
# 0                         0.000323                        -0.049532
# 1                         0.000721                        -0.031111
# 2                         0.001021                        -0.040947
# 3                         0.000505                         0.005078
# 4                         0.000150                        -0.013324
#
#     RET_2_SECTOR_DATE_INDUSTRY_std  ...  RET_6_SECTOR_DATE_INDUSTRY_var  \
# ID                                  ...
# 0                         0.025860  ...                        0.000537
# 1                         0.043367  ...                        0.002849
# 2                         0.035705  ...                        0.001518
# 3                         0.021199  ...                        0.000154
# 4                         0.027496  ...                        0.000210
#
#     RET_7_SECTOR_DATE_INDUSTRY_mean  RET_7_SECTOR_DATE_INDUSTRY_std  \
# ID
# 0                         -0.027328                        0.017969
# 1                         -0.009863                        0.033060
# 2                         -0.019393                        0.028273
# 3                         -0.028122                        0.016970
# 4                         -0.002842                        0.016459
#
#     RET_7_SECTOR_DATE_INDUSTRY_var  RET_8_SECTOR_DATE_INDUSTRY_mean  \
# ID
# 0                         0.000323                         0.016106
# 1                         0.001093                         0.010774
# 2                         0.000799                         0.009290
# 3                         0.000288                         0.016885
# 4                         0.000271                        -0.004381
#
#     RET_8_SECTOR_DATE_INDUSTRY_std  RET_8_SECTOR_DATE_INDUSTRY_var  \
# ID
# 0                         0.018315                        0.000335
# 1                         0.041196                        0.001697
# 2                         0.032437                        0.001052
# 3                         0.012985                        0.000169
# 4                         0.011274                        0.000127
#
#     RET_9_SECTOR_DATE_INDUSTRY_mean  RET_9_SECTOR_DATE_INDUSTRY_std  \
# ID
# 0                          0.035409                        0.040152
# 1                          0.020720                        0.047346
# 2                          0.033698                        0.052335
# 3                          0.006445                        0.020235
# 4                          0.005674                        0.020044
#
#     RET_9_SECTOR_DATE_INDUSTRY_var
# ID
# 0                         0.001612
# 1                         0.002242
# 2                         0.002739
# 3                         0.000409
# 4                         0.000402
#
# [5 rows x 32 columns]

# %%
from sklearn.ensemble import VotingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

cle_params = {
    "verbose": True
}

def cle_training():
    clf1 = RandomForestClassifier(n_estimators=100, max_depth=8, n_jobs=-1, random_state=0)
    clf2 = LogisticRegressionCV(random_state=0)
    clf3 = GaussianNB()
    clf4 = KNeighborsClassifier()
    clf5 = GradientBoostingClassifier(random_state=0)

    # return VotingClassifier(
    #     estimators=[('rf', clf1), ('lr', clf2), ('gnb', clf3), ('svc', clf4), ('ada', clf5)],
    #     voting="soft",
    #     verbose=True
    # )
    return GradientBoostingClassifier(
        random_state=0, 
        verbose=True, 
        learning_rate=.05,
        max_depth=2,
        warm_start=True,
        tol=1e-3,
        n_estimators=50
    )
    # return MLPClassifier(
    #     verbose=True,
    #     hidden_layer_sizes=128
    # )

# %% [markdown]
# ## Model and local score
#
# A Random Forest (RF) model is chosen for the Benchmark. We consider a large number of tree with a quiet small depth. The missing values are simply filled with 0. A KFold is done on the dates (using `DATE`) for a local scoring of the model.
#
# **Ideas of improvements**: Tune the RF hyperparameters, deal with the missing values, change the features, consider another model, ...

# %%
X_train = train[features]
y_train = train[target]

train_dates = train['DATE'].unique()
test_dates = test['DATE'].unique()

n_splits = 4
scores = []
models = []

splits = KFold(n_splits=n_splits, random_state=0,
               shuffle=True).split(train_dates)

for i, (local_train_dates_ids, local_test_dates_ids) in enumerate(splits):
    local_train_dates = train_dates[local_train_dates_ids]
    local_test_dates = train_dates[local_test_dates_ids]

    local_train_ids = train['DATE'].isin(local_train_dates)
    local_test_ids = train['DATE'].isin(local_test_dates)

    X_local_train = X_train.loc[local_train_ids]
    y_local_train = y_train.loc[local_train_ids]
    X_local_test = X_train.loc[local_test_ids]
    y_local_test = y_train.loc[local_test_ids]

    X_local_train = X_local_train.fillna(0)
    X_local_test = X_local_test.fillna(0)

    
    # model = RandomForestClassifier(**rf_params)
    model = cle_training()
    model.fit(X_local_train, y_local_train)

    y_local_pred = model.predict_proba(X_local_test)[:, 1]
    
    sub = train.loc[local_test_ids].copy()
    sub['pred'] = y_local_pred
    y_local_pred = sub.groupby('DATE')['pred'].transform(lambda x: x > x.median()).values

    models.append(model)
    score = accuracy_score(y_local_test, y_local_pred)
    scores.append(score)
    print(f"Fold {i+1} - Accuracy: {score* 100:.2f}%")

mean = np.mean(scores)*100
std = np.std(scores)*100
u = (mean + std)
l = (mean - std)
print(f'Accuracy: {mean:.2f}% [{l:.2f} ; {u:.2f}] (+- {std:.2f})')
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3861            1.62m
#          2           1.3860            1.64m
#          3           1.3858            1.63m
#          4           1.3857            1.46m
#          5           1.3856            1.40m
#          6           1.3854            1.31m
#          7           1.3853            1.22m
#          8           1.3852            1.16m
#          9           1.3851            1.11m
#         10           1.3851            1.06m
#         20           1.3842           43.94s
#         30           1.3835           28.37s
#         40           1.3828           14.01s
#         50           1.3823            0.00s
# Fold 1 - Accuracy: 50.30%
#       Iter       Train Loss   Remaining Time
#          1           1.3861            1.14m
#          2           1.3860            1.19m
#          3           1.3859            1.14m
#          4           1.3858            1.10m
#          5           1.3856            1.08m
#          6           1.3855            1.03m
#          7           1.3854            1.01m
#          8           1.3853            1.02m
#          9           1.3852           59.88s
#         10           1.3851           57.67s
#         20           1.3841           44.05s
#         30           1.3833           28.96s
#         40           1.3825           14.40s
#         50           1.3818            0.00s
# Fold 2 - Accuracy: 50.44%
#       Iter       Train Loss   Remaining Time
#          1           1.3861            1.04m
#          2           1.3860            1.03m
#          3           1.3859            1.00m
#          4           1.3858            1.01m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aryje\OneDrive\Stalinis kompiuteris\Durhack\QRT-Stock-Return-Prediction\Reg ML Algo Testing.ipynb Cell 13 in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/QRT-Stock-Return-Prediction/Reg%20ML%20Algo%20Testing.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a> # model = RandomForestClassifier(**rf_params)
#      <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/QRT-Stock-Return-Prediction/Reg%20ML%20Algo%20Testing.ipynb#X15sZmlsZQ%3D%3D?line=30'>31</a> model = cle_training()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/QRT-Stock-Return-Prediction/Reg%20ML%20Algo%20Testing.ipynb#X15sZmlsZQ%3D%3D?line=31'>32</a> model.fit(X_local_train, y_local_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/QRT-Stock-Return-Prediction/Reg%20ML%20Algo%20Testing.ipynb#X15sZmlsZQ%3D%3D?line=33'>34</a> y_local_pred = model.predict_proba(X_local_test)[:, 1]
#      <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/QRT-Stock-Return-Prediction/Reg%20ML%20Algo%20Testing.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> sub = train.loc[local_test_ids].copy()
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:586, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     583     self._resize_state()
#     585 # fit the boosting stages
# --> 586 n_stages = self._fit_stages(
#     587     X,
#     588     y,
#     589     raw_predictions,
#     590     sample_weight,
#     591     self._rng,
#     592     X_val,
#     593     y_val,
#     594     sample_weight_val,
#     595     begin_at_stage,
#     596     monitor,
#     597 )
#     599 # change shape of arrays after fit (early-stopping or additional ests)
#     600 if n_stages != self.estimators_.shape[0]:
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:663, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     656     old_oob_score = loss_(
#     657         y[~sample_mask],
#     658         raw_predictions[~sample_mask],
#     659         sample_weight[~sample_mask],
#     660     )
#     662 # fit next stage of trees
# --> 663 raw_predictions = self._fit_stage(
#     664     i,
#     665     X,
#     666     y,
#     667     raw_predictions,
#     668     sample_weight,
#     669     sample_mask,
#     670     random_state,
#     671     X_csc,
#     672     X_csr,
#     673 )
#     675 # track deviance (= loss)
#     676 if do_oob:
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:246, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     243     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     245 X = X_csr if X_csr is not None else X
# --> 246 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     248 # update tree leaves
#     249 loss.update_terminal_regions(
#     250     tree.tree_,
#     251     X,
#    (...)
#     258     k=k,
#     259 )
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:1315, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1278 def fit(
#    1279     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#    1280 ):
#    1281     """Build a decision tree regressor from the training set (X, y).
#    1282
#    1283     Parameters
#    (...)
#    1312         Fitted estimator.
#    1313     """
# -> 1315     super().fit(
#    1316         X,
#    1317         y,
#    1318         sample_weight=sample_weight,
#    1319         check_input=check_input,
#    1320         X_idx_sorted=X_idx_sorted,
#    1321     )
#    1322     return self
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
feature_importances = pd.DataFrame([model.feature_importances_ for model in models], columns=features)

sns.barplot(data=feature_importances, orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Generate the submission
#
# The same parameters of the RF model are considered. With that we build a new RF model on the entire `train` dataset. The predictions are saved in a `.csv` file.

# %%
X_test = test[features]

rf_params['random_state'] = 0
model = train()
model.fit(X_train.fillna(0), y_train)
y_pred = model.predict_proba(X_test.fillna(0))[:, 1]

sub = test.copy()
sub['pred'] = y_pred
y_pred = sub.groupby('DATE')['pred'].transform(
    lambda x: x > x.median()).values

submission = pd.Series(y_pred)
submission.index = test.index
submission.name = target

submission.to_csv('C:\\Users\\aryje\\OneDrive\\Stalinis kompiuteris\\Durhack\\QRT-Stock-Return-Prediction\\Durhackbenchmark_qrt.csv', index=True, header=True)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  1.4min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aryje\OneDrive\Stalinis kompiuteris\Durhack\Benchmark-Testing.ipynb Cell 15 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/Benchmark-Testing.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> rf_params['random_state'] = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/Benchmark-Testing.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> model = RandomForestClassifier(**rf_params)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/Benchmark-Testing.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> model.fit(X_train.fillna(0), y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/Benchmark-Testing.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> y_pred = model.predict_proba(X_test.fillna(0))[:, 1]
#       <a href='vscode-notebook-cell:/c%3A/Users/aryje/OneDrive/Stalinis%20kompiuteris/Durhack/Benchmark-Testing.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> sub = test.copy()
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:441, in BaseForest.fit(self, X, y, sample_weight)
#     430 trees = [
#     431     self._make_estimator(append=False, random_state=random_state)
#     432     for i in range(n_more_estimators)
#     433 ]
#     435 # Parallel loop: we prefer the threading backend as the Cython code
#     436 # for fitting the trees is internally releasing the Python GIL
#     437 # making threading more efficient than multiprocessing in
#     438 # that case. However, for joblib 0.12+ we respect any
#     439 # parallel_backend contexts set at a higher level,
#     440 # since correctness does not rely on using threads.
# --> 441 trees = Parallel(
#     442     n_jobs=self.n_jobs,
#     443     verbose=self.verbose,
#     444     **_joblib_parallel_args(prefer="threads"),
#     445 )(
#     446     delayed(_parallel_build_trees)(
#     447         t,
#     448         self,
#     449         X,
#     450         y,
#     451         sample_weight,
#     452         i,
#     453         len(trees),
#     454         verbose=self.verbose,
#     455         class_weight=self.class_weight,
#     456         n_samples_bootstrap=n_samples_bootstrap,
#     457     )
#     458     for i, t in enumerate(trees)
#     459 )
#     461 # Collect newly grown trees
#     462 self.estimators_.extend(trees)
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File c:\Users\aryje\AppData\Local\Programs\Python\Python39\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# The local accuracy is around 51. If we did not overfit, we shall expect something within the range above.
#
# After submitting the benchmark file at https://challengedata.ens.fr, we obtain a public score of 51.31 %.
